# %%
# !pip install numpy pandas matplotlib scipy scikit-learn -q
print("libraries installed")
# Out:
# libraries installed

# %%
import os
os.chdir('/content')
print(os.listdir('/content'))
# Out:
# ['.config', 'stock_returns.csv', 'financial_market.db', 'quant_research_engine.py', 'macro_indicators.csv', 'sql_analytics.py', 'requirements.txt', 'time_series.py', 'generate_data.py', 'stock_prices.csv', 'README.md', 'sample_data']

# %%
exec(open('quant_research_engine.py').read())
# Out:
# ...
#    QUANTITATIVE RESEARCH ENGINE — STARTING
# ...
#
# Loading data from SQLite database...
# Data loaded: 1261 days | 15 stocks
#
# [MODULE 1] SQL ANALYTICS PIPELINE
# Running SQL Analytics Queries...
# --------------------------------------------------
# Query 1 Rolling Volatility    : 18,900 rows
# Query 2 Sector Returns        : 6,300 rows
# Query 3 Extreme Days          : 150 rows
# Query 4 Cumulative Returns    : 6,300 rows
# Query 5 Volatility Regime     : 18,900 rows
# Query 6 Macro Correlation     : 13,500 rows
# Query 7 Monthly Summary       : 870 rows
# Query 8 Drawdown Analysis     : 18,915 rows
# --------------------------------------------------
# All SQL queries completed successfully
#
# [MODULE 2] TIME SERIES FORECASTING
#
# Running Time Series Analysis...
# --------------------------------------------------
#   TCS          | ADF Returns: Stationary     | RMSE: 148.81 | Dir Acc: 53.0%
#   HDFCBANK     | ADF Returns: Stationary     | RMSE: 71.45 | Dir Acc: 51.4%
# ...

# %%
# VIEW DASHBOARD
from IPython.display import Image
Image('/content/research_dashboard.png')

# %%
#time series result
import pandas as pd
df = pd.read_csv('/content/ts_forecast_results.csv')
print(df.to_string())
# Out:
#         Stock       ADF_Price ADF_Returns      RMSE       MAE  Dir_Accuracy_%  Last_Price  ARIMA_Forecast_10D
# 0         TCS      Stationary  Stationary  148.8104  119.6773            53.0     8142.27             8199.83
# 1    HDFCBANK  Non-Stationary  Stationary   71.4531   52.5950            51.4     3521.99             3541.30
# 2    RELIANCE      Stationary  Stationary   40.5592   30.7379            51.8     1848.41             1851.03
# 3  HINDUNILVR  Non-Stationary  Stationary   62.9967   49.2762            51.8     3329.73             3339.36
# 4   SUNPHARMA  Non-Stationary  Stationary   33.9529   26.0499            48.2     1204.76             1208.90

# %%
#sector performance
df2 = pd.read_csv('/content/sector_performance.csv')
print(df2.to_string())
# Out:
#        Sector  Ann Return %  Ann Volatility %  Sharpe Ratio  Total Return %
# 0          IT         17.17             18.74         0.570          135.98
# 1  Financials         30.24             20.90         1.136          353.53
# 2      Energy          6.52             23.36         0.001           38.55
# 3        FMCG         11.34             15.90         0.305           76.33
# 4  Healthcare         16.88             20.24         0.513          132.54

# %%
# MACRO RELATION
df3 = pd.read_csv('/content/macro_correlation.csv', index_col=0)
print(df3.round(3).to_string())
# Out:
#             repo_rate    cpi  usd_inr  crude_oil  nifty_vix
# TCS             0.008 -0.026    0.020     -0.034     -0.003
# HDFCBANK       -0.058  0.017   -0.041      0.004     -0.030
# RELIANCE       -0.058  0.047   -0.067      0.017     -0.055
# HINDUNILVR      0.002 -0.040    0.013     -0.056     -0.014
# SUNPHARMA      -0.020 -0.004   -0.019     -0.020     -0.006
